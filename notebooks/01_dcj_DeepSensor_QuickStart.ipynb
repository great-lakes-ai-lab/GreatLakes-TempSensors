# %% [markdown]
# # DeepSensor QuickStart
#
# This material is from the DeepSensor QuickStart documentation from the GitHub page.
#
# Here we will demonstrate a simple example of training a convolutional conditional neural process (ConvCNP) to spatially interpolate random grid cells of NCEP reanalysis air temperature data over the US. First, pip install the package. In this case we will use the PyTorch backend (note: follow the PyTorch installation instructions if you want GPU support).
#
# Feel free to experiment by changing parameters, experimenting with different datasets, and so on! You can also try out any of the other material that you find in the DeepSensor documentation:
#
# https://alan-turing-institute.github.io/deepsensor/

# %% [markdown]
# ## Install required package
#
# DeepSensor is a pip installable package, which makes our job much easier

# %%
# %pip install deepsensor
# Out:
# Requirement already satisfied: deepsensor in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (0.3.6)
# Requirement already satisfied: neuralprocesses in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from deepsensor) (0.2.7)
# Requirement already satisfied: backends-matrix in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from deepsensor) (1.3.0)
# Requirement already satisfied: backends in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from deepsensor) (1.6.6)
# Requirement already satisfied: numpy in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from deepsensor) (2.0.2)
# Requirement already satisfied: pandas in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from deepsensor) (2.2.3)
# Requirement already satisfied: xarray in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from deepsensor) (2024.7.0)
# Requirement already satisfied: dask in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from deepsensor) (2024.8.0)
# Requirement already satisfied: distributed in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from deepsensor) (2024.8.0)
# Requirement already satisfied: pyshp in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from deepsensor) (2.3.1)
# Requirement already satisfied: tqdm in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from deepsensor) (4.67.1)
# Requirement already satisfied: seaborn in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from deepsensor) (0.13.2)
# Requirement already satisfied: pooch in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from deepsensor) (1.8.2)
# Requirement already satisfied: gcsfs in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from deepsensor) (2024.12.0)
# Requirement already satisfied: zarr in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from deepsensor) (2.18.2)
# Requirement already satisfied: scipy>=1.3 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from backends->deepsensor) (1.13.1)
# Requirement already satisfied: plum-dispatch>=2.3.5 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from backends->deepsensor) (2.5.4)
# Requirement already satisfied: opt-einsum in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from backends->deepsensor) (3.4.0)
# Requirement already satisfied: wbml>=0.3 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from backends-matrix->deepsensor) (0.4.2)
# Requirement already satisfied: algebra in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from backends-matrix->deepsensor) (1.2.1)
# Requirement already satisfied: click>=8.1 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from dask->deepsensor) (8.1.7)
# Requirement already satisfied: cloudpickle>=1.5.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from dask->deepsensor) (3.1.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from dask->deepsensor) (2024.12.0)
# Requirement already satisfied: packaging>=20.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from dask->deepsensor) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from dask->deepsensor) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from dask->deepsensor) (6.0.2)
# Requirement already satisfied: toolz>=0.10.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from dask->deepsensor) (1.0.0)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from dask->deepsensor) (8.5.0)
# Requirement already satisfied: jinja2>=2.10.3 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from distributed->deepsensor) (3.1.4)
# Requirement already satisfied: locket>=1.0.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from distributed->deepsensor) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from distributed->deepsensor) (1.1.0)
# Requirement already satisfied: psutil>=5.7.2 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from distributed->deepsensor) (6.1.1)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from distributed->deepsensor) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from distributed->deepsensor) (3.0.0)
# Requirement already satisfied: tornado>=6.0.4 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from distributed->deepsensor) (6.4.2)
# Requirement already satisfied: urllib3>=1.24.3 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from distributed->deepsensor) (2.2.3)
# Requirement already satisfied: zict>=3.0.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from distributed->deepsensor) (3.0.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from gcsfs->deepsensor) (3.11.11)
# Requirement already satisfied: decorator>4.1.2 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from gcsfs->deepsensor) (5.1.1)
# Requirement already satisfied: google-auth>=1.2 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from gcsfs->deepsensor) (2.37.0)
# Requirement already satisfied: google-auth-oauthlib in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from gcsfs->deepsensor) (1.2.1)
# Requirement already satisfied: google-cloud-storage in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from gcsfs->deepsensor) (2.19.0)
# Requirement already satisfied: requests in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from gcsfs->deepsensor) (2.32.3)
# Requirement already satisfied: stheno>=1.4.2 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from neuralprocesses->deepsensor) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from pandas->deepsensor) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from pandas->deepsensor) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from pandas->deepsensor) (2024.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from pooch->deepsensor) (4.3.6)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from seaborn->deepsensor) (3.9.4)
# Requirement already satisfied: asciitree in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from zarr->deepsensor) (0.3.3)
# Requirement already satisfied: numcodecs>=0.10.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from zarr->deepsensor) (0.12.1)
# Requirement already satisfied: fasteners in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from zarr->deepsensor) (0.19)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->deepsensor) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->deepsensor) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->deepsensor) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->deepsensor) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->deepsensor) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->deepsensor) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->deepsensor) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs->deepsensor) (1.18.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from google-auth>=1.2->gcsfs->deepsensor) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from google-auth>=1.2->gcsfs->deepsensor) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from google-auth>=1.2->gcsfs->deepsensor) (4.9)
# Requirement already satisfied: zipp>=3.20 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from importlib-metadata>=4.13.0->dask->deepsensor) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from jinja2>=2.10.3->distributed->deepsensor) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->deepsensor) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->deepsensor) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->deepsensor) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->deepsensor) (1.4.7)
# Requirement already satisfied: pillow>=8 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->deepsensor) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->deepsensor) (3.2.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn->deepsensor) (6.4.5)
# Requirement already satisfied: beartype>=0.16.2 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from plum-dispatch>=2.3.5->backends->deepsensor) (0.19.0)
# Requirement already satisfied: rich>=10.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from plum-dispatch>=2.3.5->backends->deepsensor) (13.9.4)
# Requirement already satisfied: typing-extensions>=4.9.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from plum-dispatch>=2.3.5->backends->deepsensor) (4.12.2)
# Requirement already satisfied: six>=1.5 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->deepsensor) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from requests->gcsfs->deepsensor) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from requests->gcsfs->deepsensor) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from requests->gcsfs->deepsensor) (2024.12.14)
# Requirement already satisfied: fdm>=0.5.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from stheno>=1.4.2->neuralprocesses->deepsensor) (0.5.0)
# Requirement already satisfied: mlkernels>=0.3.6 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from stheno>=1.4.2->neuralprocesses->deepsensor) (0.4.0)
# Requirement already satisfied: pyarrow in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from wbml>=0.3->backends-matrix->deepsensor) (18.1.0)
# Requirement already satisfied: python-slugify in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from wbml>=0.3->backends-matrix->deepsensor) (8.0.4)
# Requirement already satisfied: netCDF4 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from wbml>=0.3->backends-matrix->deepsensor) (1.7.2)
# Requirement already satisfied: scikit-learn in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from wbml>=0.3->backends-matrix->deepsensor) (1.6.0)
# Requirement already satisfied: varz>=0.6 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from wbml>=0.3->backends-matrix->deepsensor) (0.8.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from google-auth-oauthlib->gcsfs->deepsensor) (2.0.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from google-cloud-storage->gcsfs->deepsensor) (2.24.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from google-cloud-storage->gcsfs->deepsensor) (2.4.1)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from google-cloud-storage->gcsfs->deepsensor) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from google-cloud-storage->gcsfs->deepsensor) (1.6.0)
# Requirement already satisfied: sympy in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from fdm>=0.5.0->stheno>=1.4.2->neuralprocesses->deepsensor) (1.13.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs->deepsensor) (1.66.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs->deepsensor) (5.29.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs->deepsensor) (1.25.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs->deepsensor) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs->deepsensor) (3.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from rich>=10.0->plum-dispatch>=2.3.5->backends->deepsensor) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from rich>=10.0->plum-dispatch>=2.3.5->backends->deepsensor) (2.18.0)
# Requirement already satisfied: cftime in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from netCDF4->wbml>=0.3->backends-matrix->deepsensor) (1.6.4.post1)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from python-slugify->wbml>=0.3->backends-matrix->deepsensor) (1.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from scikit-learn->wbml>=0.3->backends-matrix->deepsensor) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from scikit-learn->wbml>=0.3->backends-matrix->deepsensor) (3.5.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.0->plum-dispatch>=2.3.5->backends->deepsensor) (0.1.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages (from sympy->fdm>=0.5.0->stheno>=1.4.2->neuralprocesses->deepsensor) (1.3.0)

# %% [markdown]
# ## Load required packages
#
# This includes aspects of deepsensor, as well as xarray, pandas, numpy, and tqdm.

# %%
import deepsensor.torch
from deepsensor.data import DataProcessor, TaskLoader
from deepsensor.model import ConvNP
from deepsensor.train import Trainer

import xarray as xr
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# ## Load context dataset
#
# DeepSensor comes pre-packaged with some tutorial datasets, including an air temperature dataset that covers North America.

# %%
# Load raw data
ds_raw = xr.tutorial.open_dataset("air_temperature")
print(ds_raw)
# Out:
# <xarray.Dataset> Size: 31MB
# Dimensions:  (lat: 25, time: 2920, lon: 53)
# Coordinates:
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
# Data variables:
#     air      (time, lat, lon) float64 31MB ...
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %% [markdown]
# ## Normalize the data
#
# Next we create an instance of the DataProcessor class, which handles the normalization of xarray and pandas data for DeepSensor models.
#
# https://alan-turing-institute.github.io/deepsensor/reference/data/processor.html

# %%
# Normalise data
data_processor = DataProcessor(x1_name="lat", x2_name="lon")
ds = data_processor(ds_raw)
print(ds)
# Out:
# <xarray.Dataset> Size: 31MB
# Dimensions:  (time: 2920, x1: 25, x2: 53)
# Coordinates:
#   * time     (time) datetime64[ns] 23kB 2013-01-01 ... 2014-12-31T18:00:00
#   * x1       (x1) float32 100B 0.4615 0.4423 0.4231 ... 0.03846 0.01923 0.0
#   * x2       (x2) float32 212B 0.0 0.01923 0.03846 0.05769 ... 0.9615 0.9808 1.0
# Data variables:
#     air      (time, x1, x2) float64 31MB -2.454 -2.375 -2.313 ... 0.9151 0.8845
# Attributes:
#     Conventions:  COARDS
#     title:        4x daily NMC reanalysis (1948)
#     description:  Data is from NMC initialized reanalysis\n(4x/day).  These a...
#     platform:     Model
#     references:   http://www.esrl.noaa.gov/psd/data/gridded/data.ncep.reanaly...

# %% [markdown]
# ## Get the task loader ready
#
# Here we create an instance of the TaskLoader class, which provides a suite of sampling methods for generating Task objects for different kinds of predictions, such as: spatial interpolation, forecasting, downscaling, or some combination of these. Notice that the TaskLoader is defined by the context set and the target set, which consist of sets of variables with dimensions.
#
# https://alan-turing-institute.github.io/deepsensor/reference/data/loader.html

# %%
# Set up task loader
task_loader = TaskLoader(context=ds, target=ds)
task_loader
# Out:
# TaskLoader(1 context sets, 1 target sets)
# Context variable IDs: (('air',),)
# Target variable IDs: (('air',),)
#
# Context data dimensions: (1,)
# Target data dimensions: (1,)

# %% [markdown]
# ## Creating the ConvNP model
#
# There are a number of different possible modeling approaches. Here we are using the convolutional neural process regression model:
#
# https://alan-turing-institute.github.io/deepsensor/reference/model/convnp.html

# %%
# Set up model
model = ConvNP(data_processor, task_loader)
model
# Out:
# dim_yc inferred from TaskLoader: (1,)
# dim_yt inferred from TaskLoader: 1
# dim_aux_t inferred from TaskLoader: 0
# internal_density inferred from TaskLoader: 52
# encoder_scales inferred from TaskLoader: [np.float32(0.009615384)]
# decoder_scale inferred from TaskLoader: 0.019230769230769232

# %% [markdown]
# ## Generate training tasks
#
# Our context set consists of values from 100 random grid cells in the date range indicated below. The `task_loader` that we created above can then be used to generate the individual training tasks.

# %%
# Generate training tasks with up 100 grid cells as context and all grid cells
#   as targets
train_tasks = []
for date in pd.date_range("2013-01-01", "2014-11-30")[::7]:
    N_context = np.random.randint(0, 100)
    task = task_loader(date, context_sampling=N_context, target_sampling="all")
    train_tasks.append(task)
    
train_tasks
# Out:
# [time: Timestamp/2013-01-01 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 86)']
#  Y_c: ['ndarray/float32/(1, 86)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-01-08 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 87)']
#  Y_c: ['ndarray/float32/(1, 87)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-01-15 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 94)']
#  Y_c: ['ndarray/float32/(1, 94)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-01-22 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 96)']
#  Y_c: ['ndarray/float32/(1, 96)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-01-29 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 46)']
#  Y_c: ['ndarray/float32/(1, 46)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-02-05 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 15)']
#  Y_c: ['ndarray/float32/(1, 15)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-02-12 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 61)']
#  Y_c: ['ndarray/float32/(1, 61)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-02-19 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 58)']
#  Y_c: ['ndarray/float32/(1, 58)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-02-26 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 15)']
#  Y_c: ['ndarray/float32/(1, 15)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-03-05 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 18)']
#  Y_c: ['ndarray/float32/(1, 18)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-03-12 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 74)']
#  Y_c: ['ndarray/float32/(1, 74)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-03-19 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 65)']
#  Y_c: ['ndarray/float32/(1, 65)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-03-26 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 84)']
#  Y_c: ['ndarray/float32/(1, 84)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-04-02 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 99)']
#  Y_c: ['ndarray/float32/(1, 99)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-04-09 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 43)']
#  Y_c: ['ndarray/float32/(1, 43)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-04-16 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 20)']
#  Y_c: ['ndarray/float32/(1, 20)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-04-23 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 99)']
#  Y_c: ['ndarray/float32/(1, 99)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-04-30 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 82)']
#  Y_c: ['ndarray/float32/(1, 82)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-05-07 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 49)']
#  Y_c: ['ndarray/float32/(1, 49)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-05-14 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 43)']
#  Y_c: ['ndarray/float32/(1, 43)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-05-21 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 97)']
#  Y_c: ['ndarray/float32/(1, 97)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-05-28 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 63)']
#  Y_c: ['ndarray/float32/(1, 63)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-06-04 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 4)']
#  Y_c: ['ndarray/float32/(1, 4)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-06-11 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 90)']
#  Y_c: ['ndarray/float32/(1, 90)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-06-18 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 99)']
#  Y_c: ['ndarray/float32/(1, 99)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-06-25 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 13)']
#  Y_c: ['ndarray/float32/(1, 13)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-07-02 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 52)']
#  Y_c: ['ndarray/float32/(1, 52)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-07-09 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 77)']
#  Y_c: ['ndarray/float32/(1, 77)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-07-16 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 51)']
#  Y_c: ['ndarray/float32/(1, 51)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-07-23 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 14)']
#  Y_c: ['ndarray/float32/(1, 14)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-07-30 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 85)']
#  Y_c: ['ndarray/float32/(1, 85)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-08-06 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 95)']
#  Y_c: ['ndarray/float32/(1, 95)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-08-13 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 94)']
#  Y_c: ['ndarray/float32/(1, 94)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-08-20 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 9)']
#  Y_c: ['ndarray/float32/(1, 9)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-08-27 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 14)']
#  Y_c: ['ndarray/float32/(1, 14)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-09-03 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 72)']
#  Y_c: ['ndarray/float32/(1, 72)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-09-10 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 63)']
#  Y_c: ['ndarray/float32/(1, 63)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-09-17 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 85)']
#  Y_c: ['ndarray/float32/(1, 85)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-09-24 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 53)']
#  Y_c: ['ndarray/float32/(1, 53)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-10-01 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 5)']
#  Y_c: ['ndarray/float32/(1, 5)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-10-08 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 40)']
#  Y_c: ['ndarray/float32/(1, 40)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-10-15 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 42)']
#  Y_c: ['ndarray/float32/(1, 42)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-10-22 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 18)']
#  Y_c: ['ndarray/float32/(1, 18)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-10-29 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 0)']
#  Y_c: ['ndarray/float32/(1, 0)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-11-05 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 64)']
#  Y_c: ['ndarray/float32/(1, 64)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-11-12 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 56)']
#  Y_c: ['ndarray/float32/(1, 56)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-11-19 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 83)']
#  Y_c: ['ndarray/float32/(1, 83)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-11-26 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 8)']
#  Y_c: ['ndarray/float32/(1, 8)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-12-03 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 5)']
#  Y_c: ['ndarray/float32/(1, 5)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-12-10 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 51)']
#  Y_c: ['ndarray/float32/(1, 51)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-12-17 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 59)']
#  Y_c: ['ndarray/float32/(1, 59)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-12-24 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 53)']
#  Y_c: ['ndarray/float32/(1, 53)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2013-12-31 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 29)']
#  Y_c: ['ndarray/float32/(1, 29)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-01-07 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 66)']
#  Y_c: ['ndarray/float32/(1, 66)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-01-14 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 0)']
#  Y_c: ['ndarray/float32/(1, 0)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-01-21 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 61)']
#  Y_c: ['ndarray/float32/(1, 61)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-01-28 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 28)']
#  Y_c: ['ndarray/float32/(1, 28)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-02-04 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 36)']
#  Y_c: ['ndarray/float32/(1, 36)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-02-11 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 40)']
#  Y_c: ['ndarray/float32/(1, 40)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-02-18 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 42)']
#  Y_c: ['ndarray/float32/(1, 42)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-02-25 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 13)']
#  Y_c: ['ndarray/float32/(1, 13)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-03-04 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 22)']
#  Y_c: ['ndarray/float32/(1, 22)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-03-11 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 63)']
#  Y_c: ['ndarray/float32/(1, 63)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-03-18 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 90)']
#  Y_c: ['ndarray/float32/(1, 90)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-03-25 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 45)']
#  Y_c: ['ndarray/float32/(1, 45)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-04-01 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 84)']
#  Y_c: ['ndarray/float32/(1, 84)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-04-08 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 78)']
#  Y_c: ['ndarray/float32/(1, 78)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-04-15 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 44)']
#  Y_c: ['ndarray/float32/(1, 44)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-04-22 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 97)']
#  Y_c: ['ndarray/float32/(1, 97)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-04-29 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 41)']
#  Y_c: ['ndarray/float32/(1, 41)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-05-06 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 10)']
#  Y_c: ['ndarray/float32/(1, 10)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-05-13 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 63)']
#  Y_c: ['ndarray/float32/(1, 63)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-05-20 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 3)']
#  Y_c: ['ndarray/float32/(1, 3)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-05-27 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 8)']
#  Y_c: ['ndarray/float32/(1, 8)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-06-03 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 73)']
#  Y_c: ['ndarray/float32/(1, 73)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-06-10 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 42)']
#  Y_c: ['ndarray/float32/(1, 42)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-06-17 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 25)']
#  Y_c: ['ndarray/float32/(1, 25)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-06-24 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 19)']
#  Y_c: ['ndarray/float32/(1, 19)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-07-01 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 20)']
#  Y_c: ['ndarray/float32/(1, 20)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-07-08 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 10)']
#  Y_c: ['ndarray/float32/(1, 10)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-07-15 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 15)']
#  Y_c: ['ndarray/float32/(1, 15)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-07-22 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 64)']
#  Y_c: ['ndarray/float32/(1, 64)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-07-29 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 20)']
#  Y_c: ['ndarray/float32/(1, 20)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-08-05 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 81)']
#  Y_c: ['ndarray/float32/(1, 81)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-08-12 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 86)']
#  Y_c: ['ndarray/float32/(1, 86)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-08-19 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 2)']
#  Y_c: ['ndarray/float32/(1, 2)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-08-26 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 92)']
#  Y_c: ['ndarray/float32/(1, 92)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-09-02 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 1)']
#  Y_c: ['ndarray/float32/(1, 1)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-09-09 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 10)']
#  Y_c: ['ndarray/float32/(1, 10)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-09-16 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 28)']
#  Y_c: ['ndarray/float32/(1, 28)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-09-23 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 26)']
#  Y_c: ['ndarray/float32/(1, 26)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-09-30 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 76)']
#  Y_c: ['ndarray/float32/(1, 76)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-10-07 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 87)']
#  Y_c: ['ndarray/float32/(1, 87)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-10-14 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 2)']
#  Y_c: ['ndarray/float32/(1, 2)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-10-21 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 63)']
#  Y_c: ['ndarray/float32/(1, 63)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-10-28 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 91)']
#  Y_c: ['ndarray/float32/(1, 91)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-11-04 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 17)']
#  Y_c: ['ndarray/float32/(1, 17)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-11-11 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 5)']
#  Y_c: ['ndarray/float32/(1, 5)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-11-18 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 46)']
#  Y_c: ['ndarray/float32/(1, 46)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)'],
#  time: Timestamp/2014-11-25 00:00:00
#  ops: []
#  X_c: ['ndarray/float32/(2, 35)']
#  Y_c: ['ndarray/float32/(1, 35)']
#  X_t: [('ndarray/float32/(1, 25)', 'ndarray/float32/(1, 53)')]
#  Y_t: ['ndarray/float32/(1, 25, 53)']]

# %% [markdown]
# ## Train the model
#
# The Trainer class will actually carry out the training of the ConvNP model, using the tasks generated above. (Note that the hyperparameter `lr` is a learning rate - I misremembered it as a regularization parameter.)
#
# https://alan-turing-institute.github.io/deepsensor/reference/train/train.html

# %%
# Train model
trainer = Trainer(model, lr=5e-5)
for epoch in tqdm(range(10)):
    batch_losses = trainer(train_tasks)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages/lab/types.py:178: DeprecationWarning: numpy.core is deprecated and has been renamed to numpy._core. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.numerictypes.
#   for name in np.core.numerictypes.__all__ + ["bool"]:
# 100%|██████████| 10/10 [00:37<00:00,  3.74s/it]

# %% [markdown]
# ## Make a prediction using the fitted ConvNP model
#
# Finally, we can create a testing/prediction task to predict the air temperature on a date that was excluded from the training data. Note that the model outputs mean and standard deviation.
#
# https://alan-turing-institute.github.io/deepsensor/reference/model/pred.html

# %%
# Predict on new task with 50 context points and a dense grid of target points
test_task = task_loader("2014-12-31", context_sampling=50)
pred = model.predict(test_task, X_t=ds_raw)
pred["air"]
# Out:
# /Users/dannes/GreatLakes-TempSensors/GreatLakes-TempSensors/venv/lib/python3.9/site-packages/deepsensor/model/model.py:388: DeprecationWarning: dropping variables using `drop` is deprecated; use drop_vars.
#   X_t = X_t.isel(time=0).drop("time")
# <xarray.Dataset> Size: 11kB
# Dimensions:  (time: 1, lat: 25, lon: 53)
# Coordinates:
#   * lat      (lat) float32 100B 75.0 72.5 70.0 67.5 65.0 ... 22.5 20.0 17.5 15.0
#   * lon      (lon) float32 212B 200.0 202.5 205.0 207.5 ... 325.0 327.5 330.0
#   * time     (time) datetime64[ns] 8B 2014-12-31
# Data variables:
#     mean     (time, lat, lon) float32 5kB 257.8 257.6 257.1 ... 299.2 299.0
#     std      (time, lat, lon) float32 5kB 8.083 7.766 7.932 ... 2.312 2.423
